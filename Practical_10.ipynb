# %% [markdown]
# <a href="https://colab.research.google.com/github/MiteshMahajan15-ui/PDS-Assignment/blob/main/Practical_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Batch:- B-1
#
# Roll no.:-B-02
#
# Name:- Mitesh Mahajan

# %% [markdown]
#               Assignment- 10

# %% [markdown]
# Aim:- To study and understand Version Control using Git and GitHub, and perform basic
# operations like adding, committing, and pushing files to a repository.

# %% [markdown]
# Theory:- Version Control System (VCS) is used to track changes in files and manage different
# versions of a project. It helps multiple developers work together efficiently.
# Git is a distributed version control system that tracks changes locally on your system.
# GitHub is a cloud-based platform that hosts Git repositories and allows collaboration.
# Basic workflow in Git:
# * Create repository
# * Add files
# * Stage files (git add)
# * Commit changes (git commit)
# * Push to remote repository (git push)

# %%
from IPython.display import Image
Image(filename='/content/IMG_20260509_091217.jpg')

# %%
from IPython.display import Image
Image(filename='/content/IMG_20260509_091248.jpg')

# %%
from IPython.display import Image
Image(filename='/content/IMG_20260509_091316.jpg')

# %%
from IPython.display import Image
Image(filename='/content/IMG_20260509_091412.jpg')

# %% [markdown]
# Questions and Answers:
# 1. What is the difference between Git and GitHub?
#
# ans:  Git is a distributed version control system used to track changes in files and manage project versions locally on a computer. It allows developers to work on code, maintain history, and revert changes when needed. On the other hand, GitHub is a cloud-based platform that hosts Git repositories online and provides additional features like collaboration, sharing, issue tracking, and project management. In simple terms, Git is a tool, while GitHub is a service that uses Git.
#
# 2. Explain the difference between git add and git commit ?
#
#  The git add command is used to move changes from the working directory to the staging area, meaning it prepares the files to be committed. It does not save the changes permanently. The git commit command, however, records the staged changes into the repository along with a message describing the update. In short, git add selects the changes, while git commit saves them permanently.
#
#  3. What is the staging area in Git?
#
#  The staging area in Git is an intermediate space where changes are stored before they are committed to the repository. It allows users to review and organize changes by selecting which files or parts of files should be included in the next commit. This helps in maintaining clean and meaningful commit history by avoiding unnecessary or incomplete changes.
#
#  4. What happens if you modify a file after committing it?
#
#   If a file is modified after it has been committed, Git recognizes it as a new change and marks it as modified in the working directory. The previous committed version remains unchanged in the repository. To save the new changes, the user must again add the file to the staging area using git add and then commit it using git commit.
#
#    5. Difference between git push and git pull?
#
#   The git push command is used to upload local repository changes to a remote repository such as GitHub, making them available to others. In contrast, the git pull command is used to fetch and download changes from the remote repository and merge them into the local repository. Essentially, git push sends data from local to remote, while git pull brings updates from remote to local.
#
#    6. What is Version Control? Differentiate between Centralized and Distributed VCS?
#
#    Version Control is a system that helps track and manage changes to files over time, allowing users to maintain different versions, collaborate with others, and revert to previous states if needed. In a Centralized Version Control System (CVCS), there is a single central server that stores all versions of files, and users must connect to this server to access or modify data. In contrast, a Distributed Version Control System (DVCS), such as Git, allows every user to have a complete copy of the repository, including its full history. This makes DVCS more flexible, faster, and capable of working offline compared to centralized systems.

# %% [markdown]
# ## Conclusion
#
# This assignment provided a comprehensive overview of Version Control Systems, specifically focusing on Git and GitHub. Through practical understanding, we explored core concepts such as repository creation, staging changes with `git add`, committing modifications with `git commit`, and synchronizing with remote repositories using `git push` and `git pull`. The differentiation between Git as a distributed version control tool and GitHub as a cloud-based hosting platform for collaboration was highlighted. Furthermore, the role of the staging area in curating commits and the distinction between Centralized and Distributed VCS were clarified. This foundational knowledge is crucial for efficient software development and collaborative projects.
